# %%
'''
get tickers names and histirical prices of stocks, nasdaq, snp, nyse tickers, names, summary
'''

# %%
# !pip install yahooquery
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 56.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.0
#     Uninstalling lxml-5.3.0:
#       Successfully uninstalled lxml-5.3.0
# ...

# %%
import yfinance as yf
import pandas as pd

class StockDataFetcher:
    def __init__(self, ticker, start_date, end_date):
        self.ticker = ticker
        self.start_date = start_date
        self.end_date = end_date
        self.data = None

    def fetch_data(self):
        stock = yf.Ticker(self.ticker)
        self.data = stock.history(start=self.start_date, end=self.end_date)

    def get_prices(self):
        if self.data is not None:
            return self.data[['Open', 'High', 'Low', 'Close']]
        else:
            raise ValueError("No data found. Please run fetch_data() first.")

    def get_volume(self):
        if self.data is not None:
            return self.data['Volume']
        else:
            raise ValueError("No data found. Please run fetch_data() first.")

    def get_summary(self):
        if self.data is not None:
            return self.data.describe()
        else:
            raise ValueError("No data found. Please run fetch_data() first.")

# %%
# %%time
# Usage Example
fetcher = StockDataFetcher('GME', '2020-01-01', '2020-04-01')
fetcher.fetch_data()
print("fetcher.get_prices()")
print(fetcher.get_prices())
print("fetcher.get_volume()")
print(fetcher.get_volume())
print("fetcher.get_summary()")
print(fetcher.get_summary())
# Out:
# fetcher.get_prices()
#                              Open    High     Low   Close
# Date
# 2020-01-02 00:00:00-05:00  1.5350  1.6175  1.5175  1.5775
# 2020-01-03 00:00:00-05:00  1.5525  1.5625  1.4600  1.4700
# 2020-01-06 00:00:00-05:00  1.4500  1.4775  1.4000  1.4625
# 2020-01-07 00:00:00-05:00  1.4425  1.4575  1.3600  1.3800
# 2020-01-08 00:00:00-05:00  1.3725  1.4625  1.3525  1.4300
# ...                           ...     ...     ...     ...
# 2020-03-25 00:00:00-04:00  1.0375  1.1225  1.0100  1.0425
# 2020-03-26 00:00:00-04:00  1.0600  1.1775  1.0600  1.1025
# 2020-03-27 00:00:00-04:00  1.2350  1.2725  1.0375  1.0550
# 2020-03-30 00:00:00-04:00  1.0550  1.0675  0.9125  0.9125
# 2020-03-31 00:00:00-04:00  0.9075  0.9500  0.8750  0.8750
#
# [62 rows x 4 columns]
# fetcher.get_volume()
# Date
# 2020-01-02 00:00:00-05:00    17814400
# 2020-01-03 00:00:00-05:00    14175600
# 2020-01-06 00:00:00-05:00    13579200
# 2020-01-07 00:00:00-05:00    20912000
# ...

# %%
import yfinance as yf

def get_sp500_tickers():
    # Download the list of S&P 500 companies from Wikipedia
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    tables = pd.read_html(url)
    sp500_table = tables[0]
    sp500_tickers = sp500_table['Symbol'].tolist()
    return sp500_tickers

sp500_tickers = get_sp500_tickers()
print(sp500_tickers)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'APO', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BAX', 'BDX', 'BRK.B', 'BBY', 'TECH', 'BIIB', 'BLK', 'BX', 'BK', 'BA', 'BKNG', 'BWA', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'BXP', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CPAY', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CRWD', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', '
# ...

# %%
import pandas as pd

def get_nasdaq_tickers():
    # This link contains a CSV file of all stock tickers from NASDAQ
    url = 'https://datahub.io/core/nasdaq-listings/r/nasdaq-listed-symbols.csv'
    tickers_df = pd.read_csv(url)
    nasdaq_tickers = tickers_df['Symbol'].tolist()
    return nasdaq_tickers

nasdaq_tickers = get_nasdaq_tickers()
print(nasdaq_tickers)
# Out:
# ['AACG', 'AADI', 'AADR', 'AAL', 'AAME', 'AAOI', 'AAON', 'AAPB', 'AAPD', 'AAPL', 'AAPU', 'AAXJ', 'ABAT', 'ABCL', 'ABCS', 'ABEO', 'ABL', 'ABLLL', 'ABLLW', 'ABLV', 'ABLVW', 'ABNB', 'ABOS', 'ABP', 'ABPWW', 'ABSI', 'ABTS', 'ABUS', 'ABVC', 'ABVE', 'ABVEW', 'ABVX', 'ACAD', 'ACB', 'ACCD', 'ACDC', 'ACET', 'ACGL', 'ACGLN', 'ACGLO', 'ACHC', 'ACHL', 'ACHV', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACMR', 'ACNB', 'ACNT', 'ACOG', 'ACON', 'ACONW', 'ACRS', 'ACRV', 'ACT', 'ACTG', 'ACTU', 'ACVA', 'ACWI', 'ACWX', 'ACXP', 'ADAG', 'ADAP', 'ADBE', 'ADD', 'ADEA', 'ADGM', 'ADI', 'ADIL', 'ADMA', 'ADN', 'ADNWW', 'ADP', 'ADPT', 'ADSE', 'ADSEW', 'ADSK', 'ADTN', 'ADTX', 'ADUR', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'ADXN', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEMD', 'AENT', 'AENTW', 'AEP', 'AERT', 'AERTW', 'AEYE', 'AFBI', 'AFCG', 'AFJK', 'AFJKR', 'AFJKU', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFYA', 'AGAE', 'AGEN', 'AGFY', 'AGIO', 'AGIX', 'AGMH', 'AGMI', 'AGNC', 'AGNCL', 'AGNCM', 'AGNCN', 'AGNCO', 'AGNCP', 'AGNG', 'AGRI', 'AGY
# ...

# %%
import yfinance as yf
import pandas as pd

def get_nyse_listed_tickers():
    # This link contains a CSV file of all stock tickers from NASDAQ
    url = 'https://datahub.io/core/nyse-other-listings/r/other-listed.csv'
    #https://datahub.io/core/nyse-other-listings#other-listed
    tickers_df = pd.read_csv(url)
    nyse_tickers = tickers_df['NASDAQ Symbol'].tolist()
    nyse_company_name = tickers_df['Company Name'].tolist()
    return nyse_tickers
    # return tickers_df

# nyse_tickers = get_all_tickers()
# print(nyse_tickers)
print(get_nyse_listed_tickers())
# Out:
# ['A', 'AA', 'AAA', 'AAAU', 'AACT', 'AACT=', 'AACT+', 'AAM', 'AAM=', 'AAM+', 'AAP', 'AAPR', 'AAPX', 'AAPY', 'AAT', 'AB', 'ABBV', 'ABCB', 'ABEQ', 'ABEV', 'ABFL', 'ABG', 'ABHY', 'ABLD', 'ABLG', 'ABM', 'ABNY', 'ABOT', 'ABR', 'ABR-D', 'ABR-E', 'ABR-F', 'ABT', 'AC', 'ACA', 'ACCO', 'ACEL', 'ACES', 'ACGR', 'ACHR', 'ACHR+', 'ACI', 'ACIO', 'ACLC', 'ACLO', 'ACM', 'ACN', 'ACP', 'ACP-A', 'ACR', 'ACR-C', 'ACR-D', 'ACRE', 'ACSI', 'ACTV', 'ACU', 'ACV', 'ACVF', 'ACWV', 'ADC', 'ADC-A', 'ADCT', 'ADFI', 'ADIV', 'ADM', 'ADME', 'ADNT', 'ADPV', 'ADT', 'ADVE', 'ADX', 'AE', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEM', 'AEO', 'AEON', 'AER', 'AES', 'AESI', 'AESR', 'AETH', 'AEVA', 'AEVA+', 'AFB', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFIF', 'AFIX', 'AFK', 'AFL', 'AFLG', 'AFMC', 'AFSM', 'AG', 'AGCO', 'AGD', 'AGG', 'AGGH', 'AGGS', 'AGGY', 'AGI', 'AGIH', 'AGL', 'AGM', 'AGM-D', 'AGM-E', 'AGM-F', 'AGM-G', 'AGM.A', 'AGO', 'AGOX', 'AGQ', 'AGQI', 'AGRH', 'AGRO', 'AGS', 'AGX', 'AGZ', 'AHH', 'AHH-A', 'AHL-C', 'AHL-D', 'AHL-E', 
# ...

# %%
import yfinance as yf
import pandas as pd

def get_nyse_listed_tickers():
    # This link contains a CSV file of all stock tickers from NASDAQ
    url = 'https://datahub.io/core/nyse-other-listings/r/nyse-listed.csv'
    tickers_df = pd.read_csv(url)
    nyse_tickers = tickers_df['ACT Symbol'].tolist()
    nyse_company_name = tickers_df['Company Name'].tolist()
    # return nyse_tickers
    return tickers_df

# nyse_tickers = get_all_tickers()
# print(nyse_tickers)
print(get_nyse_listed_tickers())
# Out:
#      ACT Symbol                                       Company Name
# 0             A            Agilent Technologies, Inc. Common Stock
# 1            AA                    Alcoa Corporation Common Stock
# 2          AACT  Ares Acquisition Corporation II Class A Ordina...
# 3        AACT.U  Ares Acquisition Corporation II Units, each co...
# 4        AACT.W  Ares Acquisition Corporation II Redeemable War...
# ...         ...                                                ...
# 2881        ZTR                      Virtus Total Return Fund Inc.
# 2882        ZTS                   Zoetis Inc. Class A Common Stock
# 2883        ZUO                   Zuora, Inc. Class A Common Stock
# 2884       ZVIA                     Zevia PBC Class A Common Stock
# 2885        ZWS  Zurn Elkay Water Solutions Corporation Common ...
#
# [2886 rows x 2 columns]

# %%
from yahooquery import Screener

# Create an instance of Screener
screener = Screener()

# Define the screener criteria
data = screener.get_screeners('most_actives', count=200)

# Extract the ticker symbols
nyse_tickers = [item['symbol'] for item in data['most_actives']['quotes']]
print(nyse_tickers)
# Out:
# ['LCID', 'NVDA', 'RGTI', 'TSLA', 'SOUN', 'PLTR', 'F', 'INTC', 'NIO', 'RIVN', 'MARA', 'WULF', 'ABEV', 'ACHR', 'AMD', 'AAPL', 'SMCI', 'AMZN', 'SOFI', 'RIG', 'PFE', 'RIOT', 'NU', 'MSTR', 'WBD', 'AGNC', 'CLSK', 'MPW', 'MU', 'BTE', 'QS', 'OKLO', 'JBLU', 'T', 'SNAP', 'CSCO', 'IONQ', 'BB', 'CMCSA', 'AVGO', 'IREN', 'GOLD', 'MSFT', 'GRAB', 'WBA', 'GOOGL', 'GSAT', 'HOOD', 'HBAN', 'PCG', 'X', 'UBER', 'RXRX', 'FNMA', 'VALE', 'AAL', 'UEC', 'BAC', 'RKLB', 'VRN', 'KGC', 'LYFT', 'GOOG', 'JOBY', 'CLF', 'CVS', 'BBD', 'VZ', 'XOM', 'PARA', 'AES', 'OXY', 'HL', 'NXE', 'DVN', 'CCL', 'ALTM', 'ERIC', 'PSLV', 'NLY', 'ASX', 'LYG', 'ET', 'CSX', 'LUMN', 'AMCR', 'BA', 'VLY', 'UMC', 'RLX', 'CX', 'KMI', 'NEM', 'HIMS', 'FCX', 'PINS', 'BTG', 'BP', 'PTON', 'RF', 'BMY', 'HPE', 'WMT', 'ITUB', 'MRNA', 'PBR', 'ADT', 'ZI', 'GME', 'IOVA', 'NKE', 'KVUE', 'BABA', 'DOW', 'CVE', 'ZETA', 'U', 'DKNG', 'SLB', 'PR', 'BCS', 'RUN', 'PTEN', 'TEVA', 'CVX', 'AQN', 'KHC', 'KEY', 'XPEV', 'GERN', 'APA', 'KO', 'DJT', 'VICI', 'TAL', 'STLA', 
# ...

# %%
import pandas as pd

def get_russell1000_tickers():
    url = 'https://raw.githubusercontent.com/mcprentiss/Russell_1000_download/master/rus1000.csv'
    tickers_df = pd.read_csv(url,header=None,sep="\t")
    # russell1000_tickers = tickers_df['Symbol'].tolist()
    # return russell1000_tickers
    return (tickers_df)

russell1000_tickers = get_russell1000_tickers()
# print(russell1000_tickers)
print(russell1000_tickers)
# Out:
#          0                         1
# 0     AFL,                AFLAC INC,
# 1     ATK,      ALLIANT TECHSYSTEMS,
# 2    AGCO,                AGCO CORP,
# 3     ANV,  ALLIED NEVADA GOLD CORP,
# 4     GAS,        AGL RESOURCES INC,
# ..     ...                       ...
# 971   ACE,                  ACE LTD,
# 972  AVGO,   AVAGO TECHNOLOGIES LTD,
# 973   AWH,    ALLIED WRLD ASSUR COM,
# 974    TK,              TEEKAY CORP,
# 975  GRMN,               GARMIN LTD,
#
# [976 rows x 2 columns]
